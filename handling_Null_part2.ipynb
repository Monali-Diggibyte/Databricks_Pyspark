# %%
emp_schema = ["Employee_ID", "Name", "DOJ", "Dept_Id", "Gender", "salary"]

emp_data = [(10, "raj Kumar", "1999-01-01","100", "M", 2000),
            (20, "Ravi Kumar", "2002-02-02","200", "M", 3000),
            (30, "Arjun Kumar", "2004-03-03","400", "M", 25000),
            (40, "Rani Kumari", "2006-04-04","100", "F", 20000),
            (50, "Rekha", "2008-05-18","300", None , 9000),
            (60, "raj Kumar B", None,None, None, 2000),
            (None,None, None, None,None, None)
            ]

df_emp = spark.createDataFrame(data= emp_data, schema= emp_schema)

display(df_emp)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Reading single File
df_s = spark.read.format("csv").option("inferSchema", True).option("header", True).option("sep",",").load("/FileStore/tables/emp_details.csv")

display (df_s)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display (df_s.na.drop())

display (df_s.dropna())

display (df_s.dropna("any"))

display (df_s.dropna("all"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_id</th><th>Emp_First_name</th><th>Emp_Last_Same</th><th>Experience</th><th>Salary</th></tr></thead><tbody><tr><td>10</td><td>Monali</td><td>S.</td><td>9</td><td>60000</td></tr><tr><td>20</td><td>Harshad</td><td>K</td><td>2</td><td>25000</td></tr><tr><td>30</td><td>ABC</td><td>XYZ</td><td>3</td><td>30000</td></tr><tr><td>40</td><td>AAA</td><td>BBB</td><td>5</td><td>40000</td></tr><tr><td>50</td><td>XXX</td><td>XYZ</td><td>8</td><td>50000</td></tr><tr><td>90</td><td>klmo</td><td>xyz</td><td>7</td><td>70000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
# ...

# %%
display(df_emp)

display (df_emp.dropna("all"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_s)

display(df_s.dropna(subset= ["Experience", "Salary"]))

display(df_s.na.drop(subset= ["Experience", "Salary"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_s.printSchema()

display(df_s.na.fill(value= 0))  # if value is integer it replace only integer columns and if value is string it replace only string columns.

display(df_s.fillna(value=0))

display(df_s.fillna(value="NA"))
# Out:
# root
#  |-- Employee_id: integer (nullable = true)
#  |-- Emp_First_name: string (nullable = true)
#  |-- Emp_Last_Same: string (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_s)

display(df_s.fillna(value=0, subset=["Experience"]))

display(df_s.na.fill(value='XXX', subset=["Emp_First_name"]))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(df_s)

df_s.printSchema()

display(df_s.fillna({"Employee_id": 0, "Emp_First_name": 'Missing First name', "Emp_Last_Same":'Missing Last Name', "Experience": '0', "Salary": 0}))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
